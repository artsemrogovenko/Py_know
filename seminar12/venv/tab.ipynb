# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy
from sympy import *
import math
import pandas as pd
import seaborn as sb
penguins = sb.load_dataset("penguins")
#https://docs.google.com/document/d/1wmPgo-AOM1su0VqSj3L3C77tUUiF2BtiFQwKEgkjN_c/edit#heading=h.gjdgxs

# %%
formulaa = pd.read_csv('california_housing_test.csv')

# %%
print(formulaa)

# %%
sb.scatterplot(data=formulaa, x="population", y="households")
# Out:
# <AxesSubplot: xlabel='population', ylabel='households'>

# %%
sb.relplot(data=formulaa, x="longitude", y="median_house_value", kind="line")

# %%
sb.histplot(data=formulaa, x="housing_median_age")
# Out:
# <AxesSubplot: xlabel='housing_median_age', ylabel='Count'>

# %%
sb.histplot(data=formulaa[formulaa["housing_median_age"]>45], x="median_house_value", hue="housing_median_age")
# Out:
# <AxesSubplot: xlabel='median_house_value', ylabel='Count'>

# %%
penguins = sb.load_dataset("penguins")

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sb.scatterplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")
# Out:
# <AxesSubplot: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sb.scatterplot(data=penguins, x="flipper_length_mm", y="body_mass_g", hue="island", style = "species")
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
list_ping = ["bill_length_mm",	"bill_depth_mm",	"flipper_length_mm",	"body_mass_g"]

# %%
g = sb.PairGrid(penguins[penguins["bill_length_mm"]>45][list_ping])
g.map(sb.scatterplot)

# %%
#penguins = sb.load_dataset("penguins").pivot("flipper_length_mm", "body_mass_g", "island")

# %%
DF = pd.DataFrame(penguins[penguins["bill_length_mm"]>=10], columns = ["body_mass_g"])

# %%
data = pd.DataFrame(np.random.random((10,6)), columns=["Iron Man","Captain America","Black Widow","Thor","Hulk", "Hawkeye"])

# %%
sb.heatmap(DF)
# Out:
# <AxesSubplot: >

# %%
print(data)

# %%
penguins.loc[penguins['bill_length_mm'] >= 42, 'height_group'] = 'high'
penguins.loc[(penguins['bill_length_mm'] >= 35) & (penguins['bill_length_mm'] < 42), 'height_group'] = 'middle'
penguins.loc[penguins['bill_length_mm'] < 35, 'height_group'] = 'low'

# %%
sb.displot(penguins, x="flipper_length_mm", hue="height_group")

# %%
#Задача 44: В ячейке ниже представлен код генерирующий DataFrame, 
# которая состоит всего из 1 столбца. Ваша задача перевести его в one hot вид. Сможете ли вы это сделать без get_dummies?

import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})

# %%
data.loc[data["whoAmI"] == "human", "human"] = "1"
data.loc[data["whoAmI"] == "robot", 'robot'] = "1"
data[["human","robot"]]
data
# Out:
#    whoAmI human robot
# 0   human     1   NaN
# 1   robot   NaN     1
# 2   human     1   NaN
# 3   human     1   NaN
# 4   robot   NaN     1
# 5   human     1   NaN
# 6   human     1   NaN
# 7   human     1   NaN
# 8   robot   NaN     1
# 9   robot   NaN     1
# 10  human     1   NaN
# 11  human     1   NaN
# 12  robot   NaN     1
# 13  robot   NaN     1
# 14  human     1   NaN
# 15  robot   NaN     1
# 16  robot   NaN     1
# 17  human     1   NaN
# 18  robot   NaN     1
# 19  robot   NaN     1
